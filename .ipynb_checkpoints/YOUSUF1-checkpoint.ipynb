# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd

# %%
# dataset
data = {
    'student' :["yousuf","jhon","ufjduudj","jfjfjfj","uuuuuu"],
    'rank' : [1,2,3,4,5],
    'marks' :[22,33,44,55,66]
}
res = pd.DataFrame(data)
print("Student Records\n\n",res)
# Out:
# Student Records
#
#      student  rank  marks
# 0    yousuf     1     22
# 1      jhon     2     33
# 2  ufjduudj     3     44
# 3   jfjfjfj     4     55
# 4    uuuuuu     5     66
