# %%
import pandas as pd

data ={ "name" :["yousuf","hero","khan","don"],
       "Age" : [ 19,20,33,44,30],
       "Salary":[30000,450000,25000]}
df = pd.DataFrame(data)
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 6
#       1 import pandas as pd
#       3 data ={ "name" :["yousuf","hero","khan","don"],
#       4        "Age" : [ 19,20,33,44,30],
#       5        "Salary":[30000,450000,25000]}
# ----> 6 df = pd.DataFrame(data)
#       7 print(df)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# ...

# %%
data ={ "name" :["yousuf","hero","khan","don"],
       "Age" : [ 19,20,33,44,30],
       "Salary":[30000,450000,25000]}
df = pd.DataFrame(data)
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 4
#       1 data ={ "name" :["yousuf","hero","khan","don"],
#       2        "Age" : [ 19,20,33,44,30],
#       3        "Salary":[30000,450000,25000]}
# ----> 4 df = pd.DataFrame(data)
#       5 print(df)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# ...

# %%
data ={ "name" :["yousuf","hero","khan","don"],
       "Age" : [ 19,20,33,44],
       "Salary":[30000,450000,25000,80000]}
df = pd.DataFrame(data)
print(df)
# Out:
#   Cell In[4], line 3
#     "Salary":[30000,450000,25000],80000}
#                                       ^
# SyntaxError: ':' expected after dictionary key

# %%
data ={ "name" :["yousuf","hero","khan","don"],
       "Age" : [ 19,20,33,44],
       "Salary":[30000,450000,25000,80000]}
df = pd.DataFrame(data)
print(df)
# Out:
#      name  Age  Salary
# 0  yousuf   19   30000
# 1    hero   20  450000
# 2    khan   33   25000
# 3     don   44   80000

# %%
data = pd.read_csv("C:/Users/hp/Downloads/sample_large_dataset.csv")
print(data)
# Out:
#        ID    Name  Age    Country  Score
# 0       1  Hannah   22        USA     76
# 1       2   David   33  Australia     80
# 2       3     Eva   54      Japan     64
# 3       4  Hannah   38     Brazil     56
# 4       5   Alice   46    Germany     84
# ..    ...     ...  ...        ...    ...
# 995   996   Frank   18      Japan     55
# 996   997    Jane   52     France     87
# 997   998     Bob   39         UK     94
# 998   999  Hannah   26     Brazil     76
# 999  1000     Bob   18      India     82
#
# [1000 rows x 5 columns]

# %%
# !pip install openpyxl
data = pd.read_excel("C:/Users/hp/Downloads/sample_large_dataset.xlsx")
print(data)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#        ID    Name  Age    Country  Score
# 0       1  Hannah   22        USA     76
# 1       2   David   33  Australia     80
# 2       3     Eva   54      Japan     64
# 3       4  Hannah   38     Brazil     56
# 4       5   Alice   46    Germany     84
# ..    ...     ...  ...        ...    ...
# 995   996   Frank   18      Japan     55
# 996   997    Jane   52     France     87
# 997   998     Bob   39         UK     94
# 998   999  Hannah   26     Brazil     76
# 999  1000     Bob   18      India     82
#
# [1000 rows x 5 columns]

# %%
data = pd.read_excel("C:/Users/hp/Downloads/sample_large_dataset.xlsx")
print(data)
# Out:
#        ID    Name  Age    Country  Score
# 0       1  Hannah   22        USA     76
# 1       2   David   33  Australia     80
# 2       3     Eva   54      Japan     64
# 3       4  Hannah   38     Brazil     56
# 4       5   Alice   46    Germany     84
# ..    ...     ...  ...        ...    ...
# 995   996   Frank   18      Japan     55
# 996   997    Jane   52     France     87
# 997   998     Bob   39         UK     94
# 998   999  Hannah   26     Brazil     76
# 999  1000     Bob   18      India     82
#
# [1000 rows x 5 columns]

# %%
data = pd.read_excel("C:/Users/hp/Downloads/sample_large_dataset.xlsx")
print(data
# Out:
#   Cell In[9], line 2
#     print(data
#               ^
# SyntaxError: incomplete input

# %%
data = pd.read_excel("C:/Users/hp/Downloads/sample_large_dataset.xlsx")
print(data)
# Out:
#        ID    Name  Age    Country  Score
# 0       1  Hannah   22        USA     76
# 1       2   David   33  Australia     80
# 2       3     Eva   54      Japan     64
# 3       4  Hannah   38     Brazil     56
# 4       5   Alice   46    Germany     84
# ..    ...     ...  ...        ...    ...
# 995   996   Frank   18      Japan     55
# 996   997    Jane   52     France     87
# 997   998     Bob   39         UK     94
# 998   999  Hannah   26     Brazil     76
# 999  1000     Bob   18      India     82
#
# [1000 rows x 5 columns]

# %%
data = pd.read_excel("C:/Users/hp/Downloads/sample_large_dataset1.xlsx")
print(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 data = pd.read_excel("C:/Users/hp/Downloads/sample_large_dataset1.xlsx")
#       2 print(data)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
# ...

# %%
data = pd.read_ods("C:/Users/hp/Downloads/sample_large_dataset1.ods")
print(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 data = pd.read_ods("C:/Users/hp/Downloads/sample_large_dataset1.ods")
#       2 print(data)
#
# AttributeError: module 'pandas' has no attribute 'read_ods'

# %%
data = pd.read_excel("C:/Users/hp/Downloads/sample_large_dataset.xlsx")
print(data)
# Out:
#        ID    Name  Age    Country  Score
# 0       1  Hannah   22        USA     76
# 1       2   David   33  Australia     80
# 2       3     Eva   54      Japan     64
# 3       4  Hannah   38     Brazil     56
# 4       5   Alice   46    Germany     84
# ..    ...     ...  ...        ...    ...
# 995   996   Frank   18      Japan     55
# 996   997    Jane   52     France     87
# 997   998     Bob   39         UK     94
# 998   999  Hannah   26     Brazil     76
# 999  1000     Bob   18      India     82
#
# [1000 rows x 5 columns]

# %%
data = pd.read_excel("C:/Users/hp/Downloads/sample_large_dataset.xlsx")
print(data.head(10))
print(data.tail(10))
# Out:
#    ID    Name  Age    Country  Score
# 0   1  Hannah   22        USA     76
# 1   2   David   33  Australia     80
# 2   3     Eva   54      Japan     64
# 3   4  Hannah   38     Brazil     56
# 4   5   Alice   46    Germany     84
# 5   6    Jane   55    Germany     51
# 6   7     Eva   52  Australia     95
# 7   8   Frank   19  Australia     69
# 8   9     Bob   50     France     87
# 9  10     Eva   56      Japan     53
#        ID    Name  Age       Country  Score
# 990   991    Jane   45     Australia    100
# 991   992    Jane   41        Canada     56
# 992   993   Frank   21        France     79
# 993   994    Jane   18         India     74
# 994   995   Frank   56  South Africa     84
# 995   996   Frank   18         Japan     55
# 996   997    Jane   52        France     87
# 997   998     Bob   39            UK     94
# 998   999  Hannah   26        Brazil     76
# 999  1000     Bob   18         India     82

# %%
print(data.info)
# Out:
# <bound method DataFrame.info of        ID    Name  Age    Country  Score
# 0       1  Hannah   22        USA     76
# 1       2   David   33  Australia     80
# 2       3     Eva   54      Japan     64
# 3       4  Hannah   38     Brazil     56
# 4       5   Alice   46    Germany     84
# ..    ...     ...  ...        ...    ...
# 995   996   Frank   18      Japan     55
# 996   997    Jane   52     France     87
# 997   998     Bob   39         UK     94
# 998   999  Hannah   26     Brazil     76
# 999  1000     Bob   18      India     82
#
# [1000 rows x 5 columns]>

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       1000 non-null   int64
#  1   Name     1000 non-null   object
#  2   Age      1000 non-null   int64
#  3   Country  1000 non-null   object
#  4   Score    1000 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 39.2+ KB
# None

# %%
data.describe()
# Out:
#                 ID          Age        Score
# count  1000.000000  1000.000000  1000.000000
# mean    500.500000    38.616000    75.744000
# std     288.819436    12.323247    14.779679
# min       1.000000    18.000000    50.000000
# 25%     250.750000    28.000000    63.000000
# 50%     500.500000    38.000000    76.000000
# 75%     750.250000    49.000000    89.000000
# max    1000.000000    60.000000   100.000000

# %%
print(data.isnull())
# Out:
#         ID   Name    Age  Country  Score
# 0    False  False  False    False  False
# 1    False  False  False    False  False
# 2    False  False  False    False  False
# 3    False  False  False    False  False
# 4    False  False  False    False  False
# ..     ...    ...    ...      ...    ...
# 995  False  False  False    False  False
# 996  False  False  False    False  False
# 997  False  False  False    False  False
# 998  False  False  False    False  False
# 999  False  False  False    False  False
#
# [1000 rows x 5 columns]

# %%
print(data.isnull().sum())
# Out:
# ID         0
# Name       0
# Age        0
# Country    0
# Score      0
# dtype: int64

# %%
import pandas as pd

data = pd.DataFrame({
    "Age": [20, 25, 30, 35, 40],
    "Salary": [30000, 35000, 40000, 45000, 50000]
})

print(data.describe())
# Out:
#              Age       Salary
# count   5.000000      5.00000
# mean   30.000000  40000.00000
# std     7.905694   7905.69415
# min    20.000000  30000.00000
# 25%    25.000000  35000.00000
# 50%    30.000000  40000.00000
# 75%    35.000000  45000.00000
# max    40.000000  50000.00000
