# %%
import pandas as pd
data = pd.read_excel("C:/Users/hp/Downloads/english_student_data_with_nulls.xlsx")
print(data)
# Out:
#       Student_ID    Name Department   GPA Enrollment_Date  Passed
# 0              1   Galib        BBA  3.75      2021-07-23   False
# 1              2    Diba        BBA  3.64      2015-05-21    True
# 2              3   Emran        ENG  3.24      2015-07-23   False
# 3              4   Galib        BBA  3.99      2017-09-30   False
# 4              5  Chayon        LAW  3.47      2019-07-24   False
# ...          ...     ...        ...   ...             ...     ...
# 9995        9996    Diba        ENG  3.24      2021-04-09   False
# 9996        9997  Chayon        ENG   NaN      2019-12-27    True
# 9997        9998   Faria        EEE  3.01      2015-03-11   False
# 9998        9999   Faria        EEE  3.90      2017-12-30    True
# 9999       10000   Emran        EEE  2.84      2019-07-05   False
#
# [10000 rows x 6 columns]

# %%
import numpy as np
data["GPA"]= data["GPA"].replace(np.nan,"Yousuf")
print(data)
# Out:
#       Student_ID    Name Department     GPA Enrollment_Date  Passed
# 0              1   Galib        BBA    3.75      2021-07-23   False
# 1              2    Diba        BBA    3.64      2015-05-21    True
# 2              3   Emran        ENG    3.24      2015-07-23   False
# 3              4   Galib        BBA    3.99      2017-09-30   False
# 4              5  Chayon        LAW    3.47      2019-07-24   False
# ...          ...     ...        ...     ...             ...     ...
# 9995        9996    Diba        ENG    3.24      2021-04-09   False
# 9996        9997  Chayon        ENG  Yousuf      2019-12-27    True
# 9997        9998   Faria        EEE    3.01      2015-03-11   False
# 9998        9999   Faria        EEE     3.9      2017-12-30    True
# 9999       10000   Emran        EEE    2.84      2019-07-05   False
#
# [10000 rows x 6 columns]

# %%
data["GPA"] = data["GPA"].replace(np.nan, "Yousuf")

# %%
data.describe()
# Out:
#         Student_ID             Enrollment_Date
# count  10000.00000                       10000
# mean    5000.50000  2018-12-23 20:31:20.640000
# min        1.00000         2015-01-01 00:00:00
# 25%     2500.75000         2016-12-27 00:00:00
# 50%     5000.50000         2018-12-19 12:00:00
# 75%     7500.25000         2020-12-25 06:00:00
# max    10000.00000         2022-12-31 00:00:00
# std     2886.89568                         NaN

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Student_ID       10000 non-null  int64
#  1   Name             10000 non-null  object
#  2   Department       9500 non-null   object
#  3   GPA              10000 non-null  object
#  4   Enrollment_Date  10000 non-null  datetime64[ns]
#  5   Passed           10000 non-null  bool
# dtypes: bool(1), datetime64[ns](1), int64(1), object(3)
# memory usage: 400.5+ KB
# None

# %%
print(data.dropna())
# Out:
#       Student_ID    Name Department     GPA Enrollment_Date  Passed
# 0              1   Galib        BBA    3.75      2021-07-23   False
# 1              2    Diba        BBA    3.64      2015-05-21    True
# 2              3   Emran        ENG    3.24      2015-07-23   False
# 3              4   Galib        BBA    3.99      2017-09-30   False
# 4              5  Chayon        LAW    3.47      2019-07-24   False
# ...          ...     ...        ...     ...             ...     ...
# 9995        9996    Diba        ENG    3.24      2021-04-09   False
# 9996        9997  Chayon        ENG  Yousuf      2019-12-27    True
# 9997        9998   Faria        EEE    3.01      2015-03-11   False
# 9998        9999   Faria        EEE     3.9      2017-12-30    True
# 9999       10000   Emran        EEE    2.84      2019-07-05   False
#
# [9500 rows x 6 columns]

# %%
print(data.isnull())
# Out:
#       Student_ID   Name  Department    GPA  Enrollment_Date  Passed
# 0          False  False       False  False            False   False
# 1          False  False       False  False            False   False
# 2          False  False       False  False            False   False
# 3          False  False       False  False            False   False
# 4          False  False       False  False            False   False
# ...          ...    ...         ...    ...              ...     ...
# 9995       False  False       False  False            False   False
# 9996       False  False       False  False            False   False
# 9997       False  False       False  False            False   False
# 9998       False  False       False  False            False   False
# 9999       False  False       False  False            False   False
#
# [10000 rows x 6 columns]

# %%
print(data.isnull().sum())
# Out:
# Student_ID           0
# Name                 0
# Department         500
# GPA                  0
# Enrollment_Date      0
# Passed               0
# dtype: int64

# %%
print(data.tail(10))
# Out:
#       Student_ID    Name Department     GPA Enrollment_Date  Passed
# 9990        9991   Hasan        LAW    2.43      2020-09-10    True
# 9991        9992    Diba        EEE    3.83      2016-12-27   False
# 9992        9993   Faria        CSE    3.53      2017-08-11    True
# 9993        9994  Borsha        EEE    2.23      2022-11-07   False
# 9994        9995    Diba        BBA    2.42      2022-10-09    True
# 9995        9996    Diba        ENG    3.24      2021-04-09   False
# 9996        9997  Chayon        ENG  Yousuf      2019-12-27    True
# 9997        9998   Faria        EEE    3.01      2015-03-11   False
# 9998        9999   Faria        EEE     3.9      2017-12-30    True
# 9999       10000   Emran        EEE    2.84      2019-07-05   False

# %%
print(data.head(10))
# Out:
#    Student_ID    Name Department   GPA Enrollment_Date  Passed
# 0           1   Galib        BBA  3.75      2021-07-23   False
# 1           2    Diba        BBA  3.64      2015-05-21    True
# 2           3   Emran        ENG  3.24      2015-07-23   False
# 3           4   Galib        BBA  3.99      2017-09-30   False
# 4           5  Chayon        LAW  3.47      2019-07-24   False
# 5           6   Hasan        BBA  2.43      2017-05-10    True
# 6           7   Emran        LAW  3.69      2017-04-24   False
# 7           8   Emran        BBA  2.83      2021-06-18   False
# 8           9   Galib        LAW  2.07      2020-04-22   False
# 9          10  Borsha        BBA  2.64      2015-05-17   False
